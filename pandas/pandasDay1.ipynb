# %%
import pandas as pd
s = pd.Series([5,8,11,14,17])
print(s)
# Out:
# 0     5
# 1     8
# 2    11
# 3    14
# 4    17
# dtype: int64

# %%
s = pd.Series([5,8,11,14,17], index=['a','b','c','d','e'])
print(s)
# Out:
# a     5
# b     8
# c    11
# d    14
# e    17
# dtype: int64

# %%
data = {
    "Name": ["Raghav","Nehal","Atul"],
    "Marks": [78,92,80] 
}
df = pd.DataFrame(data)
print(df)
# Out:
#      Name  Marks
# 0  Raghav     78
# 1   Nehal     92
# 2    Atul     80

# %%
print(df.head(2))
print("\n",df.shape)
df.columns
# Out:
#      Name  Marks
# 0  Raghav     78
# 1   Nehal     92
#
#  (3, 2)
# Index(['Name', 'Marks'], dtype='object')

# %%
print(df["Name"])
# Out:
# 0    Raghav
# 1     Nehal
# 2      Atul
# Name: Name, dtype: object

# %%
df.loc[2]
# Out:
# Name     Atul
# Marks      80
# Name: 2, dtype: object

# %%
df.loc[0]
# Out:
# Name     Raghav
# Marks        78
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# Name     Raghav
# Marks        78
# Name: 0, dtype: object

# %%
df.loc[2,"Marks"]
# Out:
# np.int64(80)

# %%
df.iloc[0:3, 1]
# Out:
# 0    78
# 1    92
# 2    80
# Name: Marks, dtype: int64

# %%
print(df.loc[0:2])
df.iloc[0:2]
# Out:
#      Name  Marks
# 0  Raghav     78
# 1   Nehal     92
# 2    Atul     80
#      Name  Marks
# 0  Raghav     78
# 1   Nehal     92
