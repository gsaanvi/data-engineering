# %%
#1
try: 
    num =int(input("Enter any number: ")) 
    print(25 / num)
except ZeroDivisionError: 
    print("Error! Cannot divide by zero")
# Out:
# Error! Cannot divide by zero

# %%
#2
try: 
    num =int(input("Enter any number: ")) 
    print(num,"is valid")
except ValueError: 
    print("Invalid Input! Enter numbers only")
# Out:
# Enter numbers only

# %%
#3
try: 
    file =open("abc.txt","r") 
    print(file.read())
except FileNotFoundError: 
    print("File does not exist")
# Out:
# File does not exist

# %%
#4
try: 
    file =open("newday8Helper.txt","r") 
    print(file.readline())
except FileNotFoundError:
    print("File missing")
else:
    print("File read successfully")
# Out:
# Hello
#
# File read successfully

# %%
#5
try:
    a = int(input("Enter any num: "))
    print(a*a)
except:
    print("Error")
finally:
    print("End")
# Out:
# Error
# End

# %%
#6
age = int(input("Enter your age: "))
if age >40: 
    raise ValueError("Age must be under 45")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 4
#       2 age = int(input("Enter your age: "))
#       3 if age >40:
# ----> 4     raise ValueError("Age must be under 45")
#
# ValueError: Age must be under 45
