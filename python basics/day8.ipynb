# %%
#1
lines = ["Hello\n", "Welcome to python learnings\n", "Step1: basics\n", "Step2: Libraries\n", "Step3: ML algorithms\n"]
file=open("day8Helper.txt", "w")
file.writelines(lines)
file.close()

# %%
#2
file = open("day8Helper.txt","r")
print(file.read())
file.close()
# Out:
# Hello
# Welcome to python learnings
# Step1: basics
# Step2: Libraries
# Step3: ML algorithms

# %%
#3
file = open("day8Helper.txt","a")
file.write("Step4: Data Science, Data Analytics, etc")
file.close()

# %%
#4
file = open("day8Helper.txt","r+")
print(file.read())
file.write("\nNew Line")
file.close()
# Out:
# Hello
# Welcome to python learnings
# Step1: basics
# Step2: Libraries
# Step3: ML algorithms
# Step4: Data Science, Data Analytics, etc

# %%
#5
file = open("day8Helper.txt","r")
print(file.tell())
file.close()
# Out:
# 0

# %%
#6
file = open("day8Helper.txt","r")
file.seek(20)
print(file.read())
file.close()
# Out:
# thon learnings
# Step1: basics
# Step2: Libraries
# Step3: ML algorithms
# Step4: Data Science, Data Analytics, etc
# New Line

# %%
#7
import json
student={
    "name":"Noor",
    "course":"AI",
    "ID":"14087"
}

with open("student.json","w") as file:
    json.dump(student, file)

# %%
#8
import json
with open("student.json","r") as file: 
    data = json.load(file)
print(data["name"],"\n",data["course"],"\n",data["ID"])
# Out:
# Noor
#  AI
#  14087

# %%
#9
import os
if os.path.exists("data.txt"):
    print("File found!")
else: 
    print("File not found!")
# Out:
# File not found!

# %%
#10
import os
os.rename("day8Helper.txt","newday8Helper.txt")

# %%
#11
import os
os.mkdir("ProjectFiles")
print(os.listdir())
# Out:
# ['day1.ipynb', 'day2.ipynb', 'day3.ipynb', 'day4.ipynb', 'day5.ipynb', 'day6.ipynb', 'day7.ipynb', 'day7Helper.py', 'day8.ipynb', 'newday8Helper.txt', 'ProjectFiles', 'student.json', '__pycache__']
