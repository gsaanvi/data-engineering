# %%
#math Module
import math
print(math.sqrt(169))
print(math.factorial(10))
# Out:
# 13.0
# 3628800

# %%
#random Module
import random
print(random.randint(10, 1000))
print(random.choice(["Aarav", "Noor", "Kavya", "Gigi"]))
# Out:
# 292
# Kavya

# %%
#time Module
import time
print("5 Seconds Timer starts now...")
time.sleep(5)
print("Time Up!")
# Out:
# 5 Seconds Timer starts now...
# Time Up!

# %%
#Measure Time
import time
start = time.time()

for i in range(10000): 
    a = i*2

end = time.time()
print("Execution Time:", end - start)
# Out:
# Execution Time: 0.0013599395751953125

# %%
#statistics Module
import statistics
num= [10,20,30,60,100] 
print("Median :", statistics.median(num))
print("Mean :", statistics.mean(num))
# Out:
# Median : 30
# Mean : 44

# %%
#Create Module
import day7Helper

day7Helper.student("Kavya", 1508)
# Out:
# Welcome Kavya Please note your ID:  1508

# %%
#os Module
import os

print("Current Working Directory:", os.getcwd())
# Out:
# Current Working Directory: c:\Users\SAANVI GUPTA\Documents\data engineering AIML\python basics

# %%
#pip Practice
